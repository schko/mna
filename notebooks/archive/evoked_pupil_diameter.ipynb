# %%
import sys
 
# setting path
sys.path.append('..')

import pandas as pd
import mne
import numpy as np
import autoreject
import matplotlib.pyplot as plt
import pandas as pd
import os
import scipy
import sklearn

from mna.sessions.eye_session import process_session_eye
from mna.sessions.eeg_session import process_session_eeg
from mna.sessions.motor_session import process_session_motor
from mna.sessions.ecg_session import process_session_ecg
from mna.utils.batch_feature_extraction import clean_up_adadrive_trials

from mne.parallel import parallel_func
from mne_features.univariate import compute_hjorth_mobility,compute_pow_freq_bands
from mne.preprocessing import corrmap

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import seaborn as sns

from os import listdir
from os.path import isfile, join
from mna.utils.rnapp_data_format import read_all_lslpresets, return_metadata_from_name, event_data_from_data
import pickle

# %% [markdown]
# ### Evoked Pupil Diameter (3 sec post trial onset) function

# %%
def plot_evoked_pupil_diameter(eyetracking_df, event_df, fs, pupil):
    
    time = np.arange(0, 3, 1/freq)
    trial_onset = event_df['trial_start_time']
    baseline_samples = int(fs*0.2)
    onset_3sec_samples = int(fs*3)
    
    baseline_pupil = np.empty(len(trial_onset.index))
    onset_3sec_pupil = np.empty([len(trial_onset.index),onset_3sec_samples])

    for i in event_df.index:
        # if (trial_onset[i] == 0) or (trial_onset[i] > max(eyetracking_df.index)): 
        if (trial_onset[i]-.2 < eyetracking_df.index[0]) or (trial_onset[i] > max(eyetracking_df.index)): 
            baseline_pupil[i] = float("NaN")
            onset_3sec_pupil[i,:] = float("NaN")
        else:
            trial_baseline_pupil = eyetracking_df[pupil][(eyetracking_df.index >= trial_onset[i]-.2) & 
                                                         (eyetracking_df.index < trial_onset[i])].replace(-1, np.nan)
            
            trial_onset_3sec_pupil = eyetracking_df[pupil][(eyetracking_df.index >= trial_onset[i]) & 
                                                        (eyetracking_df.index < trial_onset[i]+3)].replace(-1, np.nan)
            
            # fill in missing values through interpolation
            trial_baseline_pupil = trial_baseline_pupil.interpolate(method ='linear', limit_direction ='forward')
            trial_onset_3sec_pupil = trial_onset_3sec_pupil.interpolate(method ='linear', limit_direction ='forward')

            # keep all trial dimension consistent through linear interpolation
            if len(trial_baseline_pupil) != baseline_samples:
                baseline_interp = scipy.interpolate.interp1d(np.arange(trial_baseline_pupil.size),trial_baseline_pupil)
                trial_baseline_pupil_interp = baseline_interp(np.linspace(0, trial_baseline_pupil.size-1, baseline_samples))
            else: 
                trial_baseline_pupil_interp = trial_baseline_pupil

            if len(trial_onset_3sec_pupil) != onset_3sec_samples:
                onset_3sec_pupil_interp = scipy.interpolate.interp1d(np.arange(trial_onset_3sec_pupil.size),trial_onset_3sec_pupil)
                trial_onset_3sec_pupil_interp = onset_3sec_pupil_interp(np.linspace(0, trial_onset_3sec_pupil.size-1, onset_3sec_samples))
            else: 
                trial_onset_3sec_pupil_interp = trial_onset_3sec_pupil

            # invalidate trials with more than half invalid samples
            if (np.isnan(trial_baseline_pupil_interp).sum() >= int(baseline_samples*.5) or 
                np.isnan(trial_onset_3sec_pupil_interp).sum() >= int(onset_3sec_samples*.5)):
                baseline_pupil[i] = float("NaN")
            else:
                baseline_pupil[i] = trial_baseline_pupil_interp.mean()
        
            # baseline correction
            onset_3sec_pupil[i,:] = trial_onset_3sec_pupil_interp - baseline_pupil[i]
    
    # evoked pupil diameter
    evoked_pupil_diameter = np.mean(onset_3sec_pupil, axis = 1)
    
    # plot easy and hard trials - averaged
    valid_baseline_trials = onset_3sec_pupil[~np.isnan(baseline_pupil)]
    easy_trials = onset_3sec_pupil[event_df['spoken_difficulty']=='easy']
    hard_trials = onset_3sec_pupil[event_df['spoken_difficulty']=='hard']

    def plot_evoked_trials(trials, line_color, fill_color, trial_label):
        trials_mean = np.nanmean(trials, axis = 0)
        trials_std = np.nanstd(trials, axis = 0)

        under_line = trials_mean - trials_std
        over_line = trials_mean + trials_std

        plt.plot(time, trials_mean, line_color, label = trial_label)
        plt.fill_between(time, under_line, over_line, color=fill_color, alpha=.1)
        plt.legend()

    plot_evoked_trials(easy_trials, 'r-', 'r', 'Easy')
    plot_evoked_trials(hard_trials, 'k-', 'k', 'Hard')
    
    return evoked_pupil_diameter

# %% [markdown]
# ## Single subject analysis

# %%
## 1. Read a RN App, converted pkl file, and create the metadata and data structure
data_dir = "../data/"
lsl_dir = "../mna/LSLPresets/"
output_dir = '../output/'

timestamp_fixer_path = f"{data_dir}annotated/fit_timestamp_adjuster.pkl"

interrupted_sessions = [(13,1), (22,1)]
# remove_sessions = [(13,1),(15,1),(22,1)]
remove_sessions = [(13,1),(15,1),(22,1),(22,102)]

if not os.path.isdir(output_dir): os.makedirs(output_dir)

onlyfiles = [f for f in listdir(data_dir) if isfile(join(data_dir, f)) and '.pkl' in f]
input_path = data_dir + onlyfiles[0] # pick a random file
print(f"input_path {input_path}")
metadata_jsons = read_all_lslpresets(path_to_jsonfiles=lsl_dir)

ts_fixer = pickle.load(open(timestamp_fixer_path, 'rb')) # features == 'processed_trial_duration',  'processed_trial_duration_1', 'lsl_timestamps'

with open(input_path, 'rb') as handle:
    rns_data = pickle.load(handle)

## Add metadata to data

for key in rns_data.keys():
    rns_data[key].append(return_metadata_from_name(key, metadata_jsons))


## 2. Create new events (trial start etc.)
event_df = event_data_from_data(rns_data, ts_fixer, remove_id_sessions=remove_sessions, interrupted_id_sessions=interrupted_sessions)

# event_df = event_data_from_data(rns_data)
event_df['trial_damage'] = event_df.damage.diff().fillna(0)
event_df['trial_duration'] = event_df.trial_end_time - event_df.trial_start_time
percent_missing = event_df.notnull().sum() / len(event_df)
summary_statistics = {}
summary_statistics['voice_success_rate'] = percent_missing['voice_timestamp']

if 'chunk_timestamp' in percent_missing:
    summary_statistics['chunk_success_rate'] = percent_missing['chunk_timestamp']
else:
    summary_statistics['chunk_success_rate'] = 0

# temporary fix for pilot phase where we had some incomplete data
if 'block_condition' not in event_df:
    event_df['block_condition'] = 'practice'
    event_df.loc[5:,'block_condition'] = 'voice'

event_df['spoken_difficulty_encoded'] = event_df.spoken_difficulty.replace(to_replace=['easy', 'hard', 'unknown'],
                                                                      value=[1, 2, None])

## create dataframe
eye_channel='Unity_ViveSREyeTracking'
df_eye = pd.DataFrame(rns_data[eye_channel][0], columns=rns_data[eye_channel][1],
                      index=rns_data[eye_channel][2]['ChannelNames']).T

# df_eye = df_eye.reset_index().rename(columns={'index':'timestamp'})

freq = rns_data[eye_channel][2]['NominalSamplingRate']
# Out:
# input_path ../data/09_14_2022_13_17_39-Exp_adadrive-Sbj_20-Ssn_3.dats.pkl

# %%
plot_evoked_pupil_diameter(df_eye, event_df, freq,'L Pupil Diameter')
# Out:
# array([        nan, -0.80390337, -0.97625156,  0.17144775,  0.11113794,
#        -0.01970601,  0.15048794, -0.01035758, -0.01821535, -0.04811367,
#        -0.09389131, -0.01092182, -0.08657464, -0.10755115, -0.10083078,
#        -0.03193325,  0.11849696,  0.06770941, -0.02213139,  0.03187976,
#        -0.15110461,  0.16070518,  0.0547223 ,  0.22451683, -0.02041291,
#         0.05006438,  0.17841814, -1.13458511,  0.00688972,  0.02892257,
#        -0.14243783,  0.06924027, -0.13245243, -0.07121298,  0.01445872,
#         0.21128947, -0.07493189, -0.05537894,  0.17165587,  0.01778662,
#         0.04729652, -0.00280575,  0.09189521,  0.00432544, -0.03122114,
#        -0.13517732,  0.1270952 ,  0.0705407 , -0.03964852,  0.0372559 ,
#         0.15460014, -0.00344717,  0.13392287, -0.03568696, -0.01661055,
#        -0.09556264, -0.01947818, -0.01047541,  0.01601431,  0.04395142,
#         0.04301181, -0.01119843, -0.01614727,  0.01568993,  0.1661243 ,
#        -0.57015593, -0.0943737 ,  0.04964909, -0.09629898,  0.09457376,
#        -0.04312685,  0.00888655,  0.03297437,  0.0710562 ,  0.07904061,
#         0.01644995,  0.14949777, -0.01291364, -0.11761657,  0.10458353])

# %%
df_eye.index[0]
# Out:
# 4298.58310739044

# %%
processed_eye_events = process_session_eye(rns_data, event_df)
# Out:
# Computed velocity exceeds threshold. Inappropriate filter setup? [3886.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2525.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2478.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1889.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3640.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2384.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2893.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1132.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1536.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2498.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1794.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2304.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1372.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3104.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2658.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1501.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1099.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2755.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2271.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1468.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1018.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3147.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2372.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3705.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1502.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2002.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1870.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2269.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2316.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2277.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1782.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2253.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1284.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2023.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1107.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1273.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1597.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1513.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1555.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1375.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1592.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1532.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1707.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1210.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1812.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1151.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1389.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1490.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1201.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1163.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1761.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2850.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1073.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3052.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2565.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1090.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1025.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1202.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1110.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2206.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2098.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1323.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2703.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2404.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1743.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1224.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1705.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2118.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1348.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3222.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1442.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2426.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2691.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1667.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1818.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1051.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1139.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1352.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1417.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2020.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1591.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1582.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1820.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1965.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1124.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1254.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1191.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1170.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1449.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1421.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2615.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1406.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1369.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1299.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1502.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1556.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1514.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1085.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1036.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1083.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1013.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1063.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1247.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1276.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1159.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1657.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1070.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1326.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1236.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1354.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1525.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1319.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1549.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2938.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2719.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1139.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2770.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2756.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3272.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1682.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2247.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3129.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1003.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1345.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1110.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1200.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2393.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1127.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2902.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2084.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2090.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2522.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2442.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1806.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2262.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3193.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1294.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1021.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1472.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1749.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2653.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2209.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1562.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1004.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1837.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1661.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1521.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2504.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1749.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1027.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1382.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1859.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1737.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1700.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1154.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1043.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1285.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1140.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1502.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1300.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1159.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1335.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1275.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2429.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1014.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1498.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1273.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1932.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1328.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1399.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1142.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1690.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2378.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2378.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1658.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1222.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2085.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2015.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1318.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1008.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1148.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2125.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2326.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1370.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1234.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1186.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1918.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2556.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1305.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1287.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1041.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1281.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2212.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2411.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1160.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1788.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1802.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1705.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1827.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1257.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1920.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2139.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1041.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1629.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1313.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1267.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1293.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1562.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2163.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1884.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1960.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3233.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2985.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3588.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1869.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1229.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1518.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1736.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1397.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2859.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2458.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3022.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3182.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1893.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1511.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1404.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1439.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2498.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2253.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [5826.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [5187.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2817.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [4077.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [4460.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [4147.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2138.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1659.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1407.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1136.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1568.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1070.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1100.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1393.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1731.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2892.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1545.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1136.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2574.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2049.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1438.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2421.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1162.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1623.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1599.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2094.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1828.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1622.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1736.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1901.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2118.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1791.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1538.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1666.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1694.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1804.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1473.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1062.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1335.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1294.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1064.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1052.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1350.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1063.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2665.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1105.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2384.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2150.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1039.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2289.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1187.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1183.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1583.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1106.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1736.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1479.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1383.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1276.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1000.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1014.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1133.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1178.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1951.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2567.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2729.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2832.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1825.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2319.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3037.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1391.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1137.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1162.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2336.4 > 1000.0 deg/s]
#  At the provided sampling rate of 97.22938725560391, the timeframe for the parameter 'min-saccade-duration' would be lower than a single sample (1.0 samples). Consider increasing the parameter value to prevent errors.
# Computed velocity exceeds threshold. Inappropriate filter setup? [1331.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1299.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1587.5 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1110.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1718.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1913.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1328.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1385.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2003.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1150.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1704.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2266.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2713.3 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2005.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2800.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2329.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2794.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3097.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [3179.4 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1522.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1976.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1897.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2712.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1874.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2087.9 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2876.0 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1223.1 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1023.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1019.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1601.7 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1558.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [2342.2 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1911.6 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1862.8 > 1000.0 deg/s]
# Computed velocity exceeds threshold. Inappropriate filter setup? [1908.4 > 1000.0 deg/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 processed_eye_events = process_session_eye(rns_data, event_df)
#
# File ~/mna/notebooks/../mna/sessions/eye_session.py:143, in process_session_eye(rns_data, event_df, eye_channel, detect_blink, pretrial_period, posttrial_period, plot_frequency, plot_eye_snippet, save_path, classifiers, plot_eye_result, pupil_average_limit)
#     140 R_Pupil_Diameter_trial_avg = pd.DataFrame(R_Pupil_Diameter_trial, columns=["Right Pupil Diameter"])
#     142 # Evoked Pupil Response (trial onset 3 second)
# --> 143 L_Pupil_3sec_evoked = pd.DataFrame(pupil_diameter_evoked(df, event_df, fs, 'L Pupil Diameter'),
#     144                              columns=["Left Evoked Pupil Diameter"])
#     145 R_Pupil__3sec_evoked = pd.DataFrame(pupil_diameter_evoked(df, event_df, fs, 'R Pupil Diameter'),
#     146                              columns=["Right Evoked Pupil Diameter"])
#     148 post_processed_event_df = pd.concat([post_processed_event_df,
#     149                                     L_Pupil_Diameter_trial_avg, R_Pupil_Diameter_trial_avg,
#     150                                     L_Pupil_3sec_evoked, R_Pupil__3sec_evoked], axis = 1)
#
# File ~/mna/notebooks/../mna/sessions/eye_session.py:246, in pupil_diameter_evoked(eyetracking_df, event_df, fs, pupil, plot_evoked_pupil)
#     244 # keep all trial dimension consistent through linear interpolation (due to inconsistent sample rate)
#     245 if len(trial_baseline_pupil) != baseline_samples:
# --> 246     baseline_interp = scipy.interpolate.interp1d(np.arange(trial_baseline_pupil.size),
#     247                                                  trial_baseline_pupil)
#     248     trial_baseline_pupil_interp = baseline_interp(np.linspace(0, trial_baseline_pupil.size-1, baseline_samples))
#     249 else:
#
# File /opt/conda/envs/mnaa/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:484, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     482 # Interpolation goes internally along the first axis
#     483 self.y = y
# --> 484 self._y = self._reshape_yi(self.y)
#     485 self.x = x
#     486 del y, x  # clean up namespace to prevent misuse; use attributes
#
# File /opt/conda/envs/mnaa/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:110, in _Interpolator1D._reshape_yi(self, yi, check)
#     107     ok_shape = "%r + (N,) + %r" % (self._y_extra_shape[-self._y_axis:],
#     108                                    self._y_extra_shape[:-self._y_axis])
#     109     raise ValueError("Data must be of shape %s" % ok_shape)
# --> 110 return yi.reshape((yi.shape[0], -1))
#
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)

# %%
processed_eye_events
# Out:
#     trial_start_time  trial_end_time  ppid  session  block  number_in_block  \
# 0           0.000000     3908.097072  12.0      1.0    1.0              1.0
# 1        3908.107072     3920.486814  12.0      1.0    1.0              2.0
# 2        3920.496814     3933.183491  12.0      1.0    1.0              3.0
# 3        3933.193491     3943.065886  12.0      1.0    1.0              4.0
# 4        3943.075886     3986.279977  12.0      1.0    1.0              5.0
# ..               ...             ...   ...      ...    ...              ...
# 63       5183.761111     5208.108798  12.0      1.0   11.0              4.0
# 64       5208.118798     5231.376608  12.0      1.0   11.0              5.0
# 65       5231.386608     5254.097690  12.0      1.0   11.0              6.0
# 66       5254.107690     5276.063566  12.0      1.0   11.0              7.0
# 67       5276.073566     5297.310183  12.0      1.0   11.0              8.0
#
#     trial   density      damage  source  ...  REMODNAV_mean_duration.Saccade  \
# 0     1.0  0.000000    0.000000     4.0  ...                        0.049978
# 1     2.0  0.100000    0.000000     4.0  ...                        0.042872
# 2     3.0  0.300000   16.203644     4.0  ...                        0.043157
# 3     4.0  0.500000   26.125107     4.0  ...                        0.041310
# 4     5.0  0.700000   34.027912     4.0  ...                        0.053107
# ..    ...       ...         ...     ...  ...                             ...
# 63   75.0  0.148238  746.601440     0.0  ...                        0.047759
# 64   76.0  0.295827  746.601440     0.0  ...                             NaN
# 65   77.0  0.769361  746.601440     0.0  ...                        0.063760
# 66   78.0  0.578679  746.601440     0.0  ...                        0.618189
# 67   79.0  0.373554  746.601440     0.0  ...                        0.047068
#
#    REMODNAV_mean_duration.Smooth Pursuit REMODNAV_count  REMODNAV_first_onset  \
# 0                               0.320939            NaN                   NaN
# 1                               0.479775            NaN                   NaN
# 2                               0.319385            NaN                   NaN
# 3                               0.381526            NaN                   NaN
# 4                               0.292654            NaN                   NaN
# ..                                   ...            ...                   ...
# 63                              0.360767            NaN                   NaN
# 64                                   NaN            NaN                   NaN
# 65                              0.356450            NaN                   NaN
# 66                              0.404123            NaN                   NaN
# 67                              0.419591            NaN                   NaN
#
#    REMODNAV_mean_duration                              REMODNAV_class_onsets  \
# 0                     NaN  [[3849.906949821412, Fixation], [3849.94858608...
# 1                     NaN  [[3908.1131594294, Fixation], [3908.1881412233...
# 2                     NaN  [[3920.498024696407, Smooth Pursuit], [3920.68...
# 3                     NaN  [[3933.195624126918, Fixation], [3933.38733201...
# 4                     NaN  [[3943.080148025521, Smooth Pursuit], [3943.52...
# ..                    ...                                                ...
# 63                    NaN  [[5183.770071967823, Fixation], [5183.82936717...
# 64                    NaN  [[5208.125448507131, nan], [5208.654610640411,...
# 65                    NaN  [[5231.394852697417, Fixation], [5231.46629682...
# 66                    NaN  [[5254.1109468674495, Saccade], [5266.76934040...
# 67                    NaN  [[5276.075801257066, Smooth Pursuit], [5276.25...
#
#     Left Pupil Diameter  Right Pupil Diameter  Left Evoked Pupil Diameter  \
# 0              2.480001              2.932532                         NaN
# 1              2.754170              3.176125                   -0.516196
# 2              2.255300              2.565652                   -0.641328
# 3              2.107097              2.386616                   -0.186731
# 4              2.210286              2.601601                    0.124909
# ..                  ...                   ...                         ...
# 63             2.188651              2.511068                    0.104543
# 64             2.215525              2.573583                    0.137968
# 65             2.432625              2.815211                    0.253194
# 66             2.229693              2.564801                    0.180914
# 67             2.151914              2.404000                   -0.004988
#
#     Right Evoked Pupil Diameter
# 0                           NaN
# 1                     -0.509417
# 2                     -0.814819
# 3                     -0.258607
# 4                      0.187253
# ..                          ...
# 63                     0.187656
# 64                     0.116741
# 65                     0.337262
# 66                     0.188116
# 67                    -0.048653
#
# [68 rows x 55 columns]

# %%
# evoked_pupil_diameter_L, post_cue_3sec_L, baseline_pupil = plot_evoked_pupil_diameter(df_eye, event_df, 
#                                                                             freq, 'L Pupil Diameter')

# # df_eye.to_csv('df_test.csv')

# %% [markdown]
# ## Batch Analysis

# %%
data_dir = "../data/"
lsl_dir = "../mna/LSLPresets/"
output_dir = '../output/'
if not os.path.isdir(output_dir): os.makedirs(output_dir)

onlyfiles = [f for f in listdir(data_dir) if isfile(join(data_dir, f)) and '.pkl' in f]
metadata_jsons = read_all_lslpresets(path_to_jsonfiles=lsl_dir)

for each_file in onlyfiles:
    input_path = data_dir + each_file
    
    sbj_id = each_file[each_file.find('Sbj_')+4:each_file.find('-Ssn')]
    ssn_no = each_file[each_file.find('Ssn_')+4:each_file.find('.dats')]
    
    if len(sbj_id) < 2: sbj = "sbj0"+sbj_id
    else: sbj = "sbj"+sbj_id
    if len(ssn_no) < 2: ssn = "ssn0"+ssn_no
    else: ssn = "ssn"+ssn_no
    
    with open(input_path, 'rb') as handle:
        rns_data = pickle.load(handle)

    ## Add metadata to data

    for key in rns_data.keys():
        rns_data[key].append(return_metadata_from_name(key, metadata_jsons))

    event_df = event_data_from_data(rns_data)
    event_df['trial_damage'] = event_df.damage.diff().fillna(0)
    event_df['trial_duration'] = event_df.trial_end_time - event_df.trial_start_time
    percent_missing = event_df.notnull().sum() / len(event_df)
    summary_statistics = {}
    summary_statistics['voice_success_rate'] = percent_missing['voice_timestamp']
    if 'chunk_timestamp' in percent_missing:
        summary_statistics['chunk_success_rate'] = percent_missing['chunk_timestamp']
    else:
        summary_statistics['chunk_success_rate'] = 0
        
    eye_channel='Unity_ViveSREyeTracking'
    df_eye = pd.DataFrame(rns_data[eye_channel][0], columns=rns_data[eye_channel][1],
                          index=rns_data[eye_channel][2]['ChannelNames']).T

    freq = rns_data[eye_channel][2]['NominalSamplingRate']

    evoked_pupil_diameter_L, post_cue_3sec_L, baseline_pupil = plot_evoked_pupil_diameter(df_eye, event_df, 
                                                                            freq, 'L Pupil Diameter')
    
    plt.savefig(f"{output_dir+'plots/'+'Left_Evoked_Pupil_Plots/'}{sbj+ssn}.png")
    plt.close()

# %% [markdown]
# # Classification

# %% [markdown]
# ## Pupil Diameter Extraction

# %%
eye_channel='Unity_ViveSREyeTracking'
df_eye = pd.DataFrame(rns_data[eye_channel][0], columns=rns_data[eye_channel][1],
                      index=rns_data[eye_channel][2]['ChannelNames']).T

n_samples = rns_data[eye_channel][2]['NominalSamplingRate']*6

label = np.empty(len(event_df.index)-1)
trials_left_pupil = np.empty([len(event_df.index)-1, n_samples])
trials_right_pupil = np.empty([len(event_df.index)-1, n_samples])

#Skip last trial because it's empty
for i in range(len(event_df.index)-1):
    L_Pupil_Diameter = np.asarray(df_eye['L Pupil Diameter'][(df_eye.index >= event_df['trial_start_time'][i]) &
                                         (df_eye.index <= event_df['trial_end_time'][i]) &
                                                   (df_eye['L Pupil Diameter'] > -1)].replace(-1, np.nan))
    trials_left_pupil[i, :] = L_Pupil_Diameter[:n_samples]

    R_Pupil_Diameter = np.asarray(df_eye['R Pupil Diameter'][(df_eye.index >= event_df['trial_start_time'][i]) &
                                         (df_eye.index <= event_df['trial_end_time'][i]) &
                                                   (df_eye['R Pupil Diameter'] > -1)].replace(-1, np.nan))
    trials_right_pupil[i, :] = R_Pupil_Diameter[:n_samples]

    label[i] = event_df.spoken_difficulty_encoded[i]

trials_left_pupil = trials_left_pupil[pd.isna(label)==False]
trials_right_pupil = trials_right_pupil[pd.isna(label)==False]
label = label[pd.isna(label)==False].astype(int)

# %% [markdown]
# ## Artifact Removal

# %%
eeg_montage = 'biosemi64'
eeg_channel = 'BioSemi'
run_autoreject=True
autoreject_epochs=20
average_reference=True
downsampling = True
n_decim = 16
low_cut=1.
hi_cut=50.

event_column='spoken_difficulty_encoded'

event_detected = event_df[event_column].notnull()
event_recognized_df = event_df[event_detected]

eeg_channel_names = mne.channels.make_standard_montage(eeg_montage).ch_names
df = pd.DataFrame(rns_data[eeg_channel][0], columns=rns_data[eeg_channel][1],
                  index=rns_data[eeg_channel][2]['ChannelNames']).T
starting_time_s = rns_data[eeg_channel][1][0]
freq = rns_data[eeg_channel][2]['NominalSamplingRate']
rna_channel_names = list(df.columns)
rna_channel_names[1:65] = eeg_channel_names
info = mne.create_info(ch_names=rna_channel_names, ch_types=['stim'] + ['eeg'] * 64 + ['ecg'] * 2 + ['misc'] * 22,
                       sfreq=freq)
info.set_montage(eeg_montage)

raw = mne.io.RawArray(df.T * 1e-6, info)
raw = raw.pick(['eeg'])
if average_reference:
    raw = raw.set_eeg_reference(ref_channels='average')  # set average reference
if low_cut or hi_cut:
    raw.filter(l_freq=low_cut, h_freq=hi_cut, verbose=False)
if downsampling:
    raw.resample(freq/n_decim)

freq /= n_decim
    
trial_start_time = event_recognized_df.trial_start_time - starting_time_s  # reference for mne
event_values = event_recognized_df[event_column].values
events = np.column_stack((trial_start_time.values * freq,
                          np.zeros(len(event_recognized_df), dtype=int),
                          event_values)).astype(int)
event_dict = dict(easy=1, hard=2)
epochs = mne.Epochs(raw, events, event_id=event_dict, baseline = (None, None), tmin=-3, tmax=0, preload=True, on_missing='warn')

event_recognized_df = event_recognized_df[[e==() for e in epochs.drop_log]] # only keep good epochs in event_df

# %%
#Autoreject
if len(epochs) < 10: # we need at least 10 epochs to run autoreject for cross validation
    bad_epochs = pd.Series(np.full(len(event_df),np.NAN), index=event_df.index, name='autorejected')
    event_df = event_df.join(bad_epochs)
    reject_log = None

elif run_autoreject:
    ar = autoreject.AutoReject(random_state=11, n_jobs=2, verbose=False)
    ar.fit(epochs[:autoreject_epochs])  # fit on a few epochs to save time
    epochs_ar, reject_log = ar.transform(epochs, return_log=True)
    bad_epochs = pd.Series(reject_log.bad_epochs, index=event_recognized_df.index, dtype=bool, name='autorejected')
    event_df = event_df.join(bad_epochs) # creates nan if not processed at all
    epochs = epochs_ar

# %%
# epochs.drop_log
# event_df
raw.plot()

# %%
ica = mne.preprocessing.ICA(n_components=64, random_state=64)
ica.fit(raw)

# %%
# ica.plot_sources(epochs[:10], picks=[0,1,2,3,4,5])
ica.plot_components()

# %%
ica.plot_sources(epochs[:10], picks=[0,1,2,3,4,5])

# %%
# Artifact Detection
eog_idx, eog_scores = ica.find_bads_eog(raw, ch_name = ['Fp1', 'Fp2'])
# ecg_idx, ecg_scores = ica.find_bads_ecg(raw, method='ctps', measure='correlation', threshold="auto")
# muscle_idx, muscle_scores = ica.find_bads_muscle(raw)

# print([eog_idx, ecg_idx, muscle_idx])
print([eog_idx])

# ica.plot_scores(eog_scores, exclude=eog_idx)
# ica.plot_scores(ecg_scores, exclude=ecg_idx)
# ica.plot_scores(muscle_scores, exclude=muscle_idx)

# first half all non-ECG component (EOG component was identified as ECG component as well). second half eog component
# non_ECG_comp = list(set(np.arange(ica.n_components_)).symmetric_difference(set(ecg_idx))) + \
#                list(set(ecg_idx).intersection(set(eog_idx)))

# %%
# Identified Artifact Component Removal
eeg_data_ICA = raw.copy()
# ica.apply(eeg_data_ICA, exclude=eog_idx+ecg_idx+muscle_idx)
# ica.apply(eeg_data_ICA, exclude=eog_idx+ecg_idx)
ica.apply(eeg_data_ICA, exclude=eog_idx)
# ica.apply(eeg_data_ICA, exclude=non_ECG_comp)

eeg_data_ICA_epochs = mne.Epochs(eeg_data_ICA, events, event_id=event_dict, baseline = (None, None), tmin=-3, tmax=0, preload=True, on_missing='warn')

del eeg_data_ICA

# %%
# plot before and after component removal signal
# epochs.plot(n_channels=10, n_epochs=5, show_scrollbars=False)
# eeg_data_ICA.plot(n_channels=10, n_epochs=5, show_scrollbars=False)

# %% [markdown]
# ## Trial Difficulty Classification

# %%
from sklearn.model_selection import train_test_split
from mne_features.univariate import compute_hjorth_mobility,compute_pow_freq_bands

# Dataset Split - EEG
x_train_raw, x_test_raw, y_train_raw, y_test_raw = train_test_split(epochs.get_data()[:,:64,:], epochs.events[:,2], random_state=64, test_size=10)
x_train_AR, x_test_AR, y_train_AR, y_test_AR = train_test_split(eeg_data_ICA_epochs.get_data()[:,:64,:], eeg_data_ICA_epochs.events[:,2],
                                                                    random_state=64, test_size=10)

# Dataset Split - Pupil Diameter
x_train_pupil, x_test_pupil, y_train_pupil, y_test_pupil = train_test_split(trials_left_pupil, label, random_state=64, test_size=10)

# Feature extraction
def eeg_feature(train_raw, test_raw, train_ar, test_ar, method, band_intervals = None):

    if method == 'psd':

        band_freq = band_intervals

        train_feature_raw = np.empty([len(train_raw), len(eeg_channel_names)*(len(band_freq)-1)])
        test_feature_raw = np.empty([len(test_raw), len(eeg_channel_names)*(len(band_freq)-1)])
        train_feature_ar = np.empty([len(train_ar), len(eeg_channel_names)*(len(band_freq)-1)])
        test_feature_ar = np.empty([len(test_ar), len(eeg_channel_names)*(len(band_freq)-1)])

        for i in range(len(train_raw)):

            train_feature_raw[i,:] = compute_pow_freq_bands(freq, train_raw[i], freq_bands = band_freq)
            train_feature_ar[i,:] = compute_pow_freq_bands(freq, train_ar[i], freq_bands = band_freq)

        for j in range(len(test_raw)):
            test_feature_raw[j,:] = compute_pow_freq_bands(freq, test_raw[j], freq_bands = band_freq)
            test_feature_ar[j,:] = compute_pow_freq_bands(freq, test_ar[j], freq_bands = band_freq)

    if method == 'hjorth_mobility':
        train_feature_raw = compute_hjorth_mobility(train_raw)
        test_feature_raw = compute_hjorth_mobility(test_raw)

        train_feature_ar = compute_hjorth_mobility(train_ar)
        test_feature_ar = compute_hjorth_mobility(test_ar)

    if method == "temporal_avg":
        train_feature_raw = np.mean(x_train_AR, axis = -1)
        test_feature_raw = np.mean(x_test_AR, axis = -1)

        train_feature_ar = np.mean(x_train_raw, axis = -1)
        test_feature_ar = np.mean(x_test_raw, axis = -1)

    return train_feature_raw, test_feature_raw, train_feature_ar, test_feature_ar

# call function for eeg feature extraction
raw_train_feature, raw_test_feature, AR_train_feature, AR_test_feature = eeg_feature(x_train_raw, x_test_raw, 
                                                                                     x_train_AR, x_test_AR, 
                                                                                     'psd', band_intervals = np.array([3,8,13,30,64]))

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import seaborn as sns

# Trial Difficulty Classification Function
def spoken_difficulty_classification(train_data, test_data, train_label, test_label, method):

    if method == 'logistic':

        logreg = LogisticRegression(solver="liblinear", random_state=0).fit(train_data, train_label)
        score_train = logreg.decision_function(train_data)
        score_test = logreg.decision_function(test_data)

        train_pred = logreg.predict(train_data)
        test_pred = logreg.predict(test_data)

    if method == 'svm':

        svm_classifer = SGDClassifier(random_state=0).fit(train_data, train_label)
        score_train = svm_classifer.decision_function(train_data)
        score_test = svm_classifer.decision_function(test_data)

        train_pred = svm_classifer.predict(train_data)
        test_pred = svm_classifer.predict(test_data)

    if method == 'knn':
        kNN = KNeighborsClassifier(n_neighbors = 3).fit(train_data, train_label)

        score_train = kNN.predict_proba(train_data)[:,1]
        score_test = kNN.predict_proba(test_data)[:,1]

        train_pred = (score_train > 0.5) + 0
        test_pred = (score_test >0.5) + 0

    fpr_train, tpr_train, thresholds_train = metrics.roc_curve(train_label-1, score_train)
    ROC_score_train = metrics.roc_auc_score (train_label-1, score_train)

    fpr_test, tpr_test, thresholds_test = metrics.roc_curve(test_label-1, score_test)
    ROC_score_test = metrics.roc_auc_score (test_label-1, score_test)

    train_acc = metrics.accuracy_score(train_label,train_pred)
    test_acc = metrics.accuracy_score(test_label,test_pred)

    # ROC Curve
    fig = plt.figure(figsize = [10 ,3])

    axe = fig.add_subplot(1,2,1)
    axe.plot(fpr_train,tpr_train)
    axe.set_xlabel("False Positive Rate")
    axe.set_ylabel("True Positive Rate")
    axe.set_title("Training ROC Curve")
    axe.text(0.6,0.2,"ROC Score = {:.2f}".format(ROC_score_train))

    axe = fig.add_subplot(1,2,2)
    axe.plot(fpr_test,tpr_test)
    axe.set_xlabel("False Positive Rate")
    axe.set_ylabel("True Positive Rate")
    axe.set_title("Testing ROC Curve")
    axe.text(0.6,0.2,"ROC Score = {:.2f}".format(ROC_score_test))

    # plt.grid(visible=False)
    # Confusion Matrix
    # fig, (ax1, ax2) = plt.subplots(1,2)
    fig_cnf = plt.figure(figsize = [10 ,3])
    ax1 = fig_cnf.add_subplot(1,2,1)
    ax2 = fig_cnf.add_subplot(1,2,2)

    cnf_matrix_train = metrics.confusion_matrix(train_label, train_pred)
    cnf_matrix_test = metrics.confusion_matrix(test_label, test_pred)

    sns.heatmap(cnf_matrix_train, annot = True, xticklabels = ['Easy','Hard'], yticklabels = ['Easy','Hard'],ax=ax1)
    ax1.set_title("Training Confusion Matrix")
    sns.heatmap(cnf_matrix_test, annot = True, xticklabels = ['Easy','Hard'], yticklabels = ['Easy','Hard'],ax=ax2)
    ax2.set_title("Testing Confusion Matrix")
    plt.show()

    return test_pred, train_pred, train_acc, test_acc

# %%
# Trial Difficulty Classification - Pupil Diameter
test_pred_raw, train_pred_raw, train_acc_raw, test_acc_raw = spoken_difficulty_classification(x_train_pupil, x_test_pupil,y_train_pupil, y_test_pupil, 'logistic')

# print(f"Training Accuracy with Pupil Diameter: {train_acc_raw:.2f} \n"
#       f"Train Label:      {y_train_raw} \n"
#       f"Train Prediction: {train_pred_raw} \n"
#       f"Test Accuracy with Pupil Diameter: {test_acc_raw:.2f} \n"
#       f"Test Label:      {y_test_raw} \n"
#       f"Test Prediction: {test_pred_raw}\n")

# %%
# Trial Difficulty Classification - Raw EEG
test_pred_raw, train_pred_raw, train_acc_raw, test_acc_raw = spoken_difficulty_classification(raw_train_feature, raw_test_feature,y_train_raw, y_test_raw, 'logistic')

# print(f"Training Accuracy without Artifacts Removal: {train_acc_raw:.2f} \n"
#       f"Train Label:      {y_train_raw} \n"
#       f"Train Prediction: {train_pred_raw} \n"
#       f"Test Accuracy without Artifacts Removal: {test_acc_raw:.2f} \n"
#       f"Test Label:      {y_test_raw} \n"
#       f"Test Prediction: {test_pred_raw}\n")

# %%
# Trial Difficulty Classification - Artifacts Removed EEG

test_pred_AR, train_pred_AR, train_acc_AR, test_acc_AR = spoken_difficulty_classification(AR_train_feature, AR_test_feature,y_train_AR, y_test_AR, 'logistic')

# print(f"Training Accuracy with Artifacts Removal: {train_acc_AR:.2f} \n"
#       f"Training Label:      {y_train_AR} \n"
#       f"Training Prediction: {train_pred_AR} \n"
#       f"Test Accuracy with Artifacts Removal: {test_acc_AR:.2f} \n"
#       f"Test Label:      {y_test_AR} \n"
#       f"Test Prediction: {test_pred_AR}")

# %% [markdown]
# ## ICA-Adaptive Filter - WIP

# %%
# ! pip install EMD-signal

# %%
# !pip install EMD-signal
# # import PyEMD
# from PyEMD import EMD, Visualisation

# eeg_comps = ica.get_sources(raw).get_data() #eeg componenets for all epochs
# # eeg_comps = ica.get_sources(epochs).get_data() #eeg componenets for all epochs
# # comps_epoch_concat = np.empty([eeg_comps.shape[1],eeg_comps.shape[2]*eeg_comps.shape[0]]) #initiate empty array
# # for i in range(eeg_comps.shape[0]):
# #     comps_epoch_concat[:,i*eeg_comps.shape[2]:eeg_comps.shape[2]*(i+1)] = eeg_comps[i]

# component_no = 5
# test_comps = eeg_comps[component_no]

# emd = EMD() # EMD instantiation
# emd.emd(test_comps) # decompose signal into IMFs and residue
# imfs, res = emd.get_imfs_and_residue()

# # # imfs = emd(np.squeeze(eeg_comps[0])[0])

# %%
# scipy.stats.kurtosis(test_comps)

# %%
# # Visualization
# t = np.arange(0, 3+1/freq, 1/freq)
# vis = Visualisation()
# vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
# # vis.plot_instant_freq(t, imfs=imfs)
# vis.show()
